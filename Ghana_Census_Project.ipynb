# %% [markdown]
# <a href="https://colab.research.google.com/github/csmith3051/HU-DS-Bootcamp/blob/Ghana_Project/Ghana_Census_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the libraries
import numpy as np                  # Scientific Computing
import pandas as pd                 # Data Analysis
import matplotlib.pyplot as plt     # Plotting
import seaborn as sns               # Statistical Data Visualization

# Let's make sure pandas returns all the rows and columns for the dataframe
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Force pandas to display full numbers instead of scientific notation
# pd.options.display.float_format = '{:.0f}'.format

# %%
# !git clone https://github.com/laketalkemp/2025-HUDS-Bootcamp.git
# Out:
# Cloning into '2025-HUDS-Bootcamp'...
# remote: Enumerating objects: 827, done.
# remote: Counting objects: 100% (242/242), done.
# remote: Compressing objects: 100% (241/241), done.
# remote: Total 827 (delta 143), reused 1 (delta 1), pack-reused 585 (from 2)
# Receiving objects: 100% (827/827), 207.66 MiB | 11.71 MiB/s, done.
# Resolving deltas: 100% (327/327), done.
# Updating files: 100% (349/349), done.

# %%
# !pip install pyreadstat
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 617.7/617.7 kB 7.1 MB/s eta 0:00:00
# ...

# %%
import glob

# List all Stata files in the directory
dta_files = glob.glob('2025-HUDS-Bootcamp/Data/THREADS/Wave_3/*.dta')
print(dta_files)
# Out:
# ['2025-HUDS-Bootcamp/Data/THREADS/Wave_3/03aiii_durablegoodquestions.dta', '2025-HUDS-Bootcamp/Data/THREADS/Wave_3/03aiii_durablegoodquestions_osp.dta', '2025-HUDS-Bootcamp/Data/THREADS/Wave_3/05_bizsection.dta', '2025-HUDS-Bootcamp/Data/THREADS/Wave_3/08b_power.dta', '2025-HUDS-Bootcamp/Data/THREADS/Wave_3/04_plotroster.dta', '2025-HUDS-Bootcamp/Data/THREADS/Wave_3/04i_landtenure.dta', '2025-HUDS-Bootcamp/Data/THREADS/Wave_3/03bi_borrowingquestions.dta', '2025-HUDS-Bootcamp/Data/THREADS/Wave_3/03bvi_mobile_money_agents.dta', '2025-HUDS-Bootcamp/Data/THREADS/Wave_3/01evii_anthropometry.dta', '2025-HUDS-Bootcamp/Data/THREADS/Wave_3/03biii_outtransfersquestions.dta', '2025-HUDS-Bootcamp/Data/THREADS/Wave_3/03ai_animalquestions.dta', '2025-HUDS-Bootcamp/Data/THREADS/Wave_3/04o_cropsalesstoresservices.dta', '2025-HUDS-Bootcamp/Data/THREADS/Wave_3/03ai_animalquestions_osp.dta', '2025-HUDS-Bootcamp/Data/THREADS/Wave_3/02a_nr_relatives_roster.dta', '2025-HUDS-Bootcamp/Data/THREADS/Wave_3/08
# ...

# %%
import pandas as pd
df = pd.read_stata('2025-HUDS-Bootcamp/Data/THREADS/Wave_3/00_hh_info.dta')
df.head(30)
# Out:
#      FPrimary         round                            remnant  \
# 0   301018041     Split off                                 No
# 1   108307004          Main                                 No
# 2   206204035          Main                                 No
# 3   106192028          Main                                 No
# 4   206199003          Main                                 No
# 5   106197037          Main                                 No
# 6   106197015          Main                                 No
# 7   106197023          Main                                 No
# 8   106197001          Main                                 No
# 9   107242071          Main                                 No
# 10  106206008          Main                                 No
# 11  106201026          Main                                 No
# 12  206236013     Split off                                 No
# 13  207271028          Main                                 No
# ...
